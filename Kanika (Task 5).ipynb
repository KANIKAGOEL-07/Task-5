# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("C:\\Users\\rites\\OneDrive\\Desktop\\titles.csv")

# %%
df.head()
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
#
#                                          description  release_year  runtime  \
# 0  This collection includes 12 World War II-era p...          1945       51
# 1  A mentally unstable Vietnam War veteran works ...          1976      114
# 2  Intent on seeing the Cahulawassee River before...          1972      109
# 3  King Arthur, accompanied by his squire, recrui...          1975       91
# 4  12 American military prisoners in World War II...          1967      150
#
#                                         genres production_countries  \
# 0                            ['documentation']               ['US']
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year', 'runtime',
#        'genres', 'production_countries', 'imdb_id', 'imdb_score', 'imdb_votes',
#        'tmdb_popularity', 'tmdb_score'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5850 entries, 0 to 5849
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    5850 non-null   object
#  1   title                 5849 non-null   object
#  2   type                  5850 non-null   object
#  3   description           5832 non-null   object
#  4   release_year          5850 non-null   int64
#  5   runtime               5850 non-null   int64
#  6   genres                5850 non-null   object
#  7   production_countries  5850 non-null   object
#  8   imdb_id               5447 non-null   object
#  9   imdb_score            5368 non-null   float64
#  10  imdb_votes            5352 non-null   float64
#  11  tmdb_popularity       5759 non-null   float64
#  12  tmdb_score            5539 non-null   float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 594.3+ KB

# %%
df.shape
# Out:
# (5850, 13)

# %%
df.isnull().sum()
# Out:
# id                        0
# title                     1
# type                      0
# description              18
# release_year              0
# runtime                   0
# genres                    0
# production_countries      0
# imdb_id                 403
# imdb_score              482
# imdb_votes              498
# tmdb_popularity          91
# tmdb_score              311
# dtype: int64

# %%
x=df["title"].mode()

# %%
df["title"].fillna(x,inplace=True)

# %%
y=df["description"].mode()

# %%
df["description"].fillna(y[0],inplace=True)

# %%
z=df["imdb_id"].mode()

# %%
df["imdb_id"].fillna(z,inplace=True)

# %%
a=df["imdb_score"].mean()
a
# Out:
# 6.510860655737705

# %%
df["imdb_score"].fillna(a,inplace=True)

# %%
b=df["imdb_votes"].mean()
b
# Out:
# 23439.382473841553

# %%
df["imdb_votes"].fillna(b,inplace=True)

# %%
c=df["tmdb_popularity"].mean()
c
# Out:
# 22.63792539568432

# %%
df["tmdb_popularity"].fillna(c,inplace=True)

# %%
d=df["tmdb_score"].mean()
d
# Out:
# 6.829174760787145

# %%
df["tmdb_score"].fillna(c,inplace=True)

# %%
df.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# description             0
# release_year            0
# runtime                 0
# genres                  0
# production_countries    0
# imdb_id                 0
# imdb_score              0
# imdb_votes              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
plt.hist(df["runtime"],bins=5,color="pink",edgecolor="blue")
plt.title("show runtime",fontweight="bold",fontsize=20)
plt.show()

# %%
plt.scatter(df["release_year"],df["imdb_score"],c="red")
plt.title("Scatter plot of imdb_score vs release_year of titles",fontweight="bold",fontsize=20)

plt.show()

# %%
df.isnull().sum()
# Out:
# id                        0
# title                     1
# type                      0
# description              18
# release_year              0
# runtime                   0
# genres                    0
# production_countries      0
# imdb_id                 403
# imdb_score              482
# imdb_votes              498
# tmdb_popularity          91
# tmdb_score              311
# dtype: int64

# %%
sns.boxplot(y=df["imdb_score"],x=df["type"])
plt.xticks(rotation=45)
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
data=df.describe()
sns.heatmap(data, cmap='viridis')
plt.title('Simple Heatmap')
plt.show()
